# %%
# Importing libraries

import numpy as np
import pandas as pd

# %%
#loading the file

df=pd.read_csv("C:\\Users\\abypt\\OneDrive\\Documents\\Harkeerat\\DATASETS for projects\\Iris_data_sample.csv")

df.head()
# Out:
#    Unnamed: 0 SepalLengthCm  SepalWidthCm PetalLengthCm  PetalWidthCm  \
# 0           1           5.1           3.5           1.4           0.2
# 1           2           4.9           NaN           1.4           0.2
# 2           3           4.7           3.2           1.3           0.2
# 3           4            ??           3.1           1.5           0.2
# 4           5             5           3.6           ###           0.2
#
#        Species
# 0  Iris-setosa
# 1          NaN
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
# To remove the unwanted column
df=pd.read_csv("C:\\Users\\abypt\\OneDrive\\Documents\\Harkeerat\\DATASETS for projects\\Iris_data_sample.csv",index_col=0)

df.head()
# Out:
#   SepalLengthCm  SepalWidthCm PetalLengthCm  PetalWidthCm      Species
# 1           5.1           3.5           1.4           0.2  Iris-setosa
# 2           4.9           NaN           1.4           0.2          NaN
# 3           4.7           3.2           1.3           0.2  Iris-setosa
# 4            ??           3.1           1.5           0.2  Iris-setosa
# 5             5           3.6           ###           0.2  Iris-setosa

# %%
#missing values
df.isnull().head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 1          False         False          False         False    False
# 2          False          True          False         False     True
# 3          False         False          False         False    False
# 4          False         False          False         False    False
# 5          False         False          False         False    False

# %%
# To count missing values
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     1
# PetalLengthCm    1
# PetalWidthCm     0
# Species          1
# dtype: int64

# %%
df=pd.read_csv("C:\\Users\\abypt\\OneDrive\\Documents\\Harkeerat\\DATASETS for projects\\Iris_data_sample.csv",index_col=0, 
               na_values=["??","###"])
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1            5.1           3.5            1.4           0.2  Iris-setosa
# 2            4.9           NaN            1.4           0.2          NaN
# 3            4.7           3.2            1.3           0.2  Iris-setosa
# 4            NaN           3.1            1.5           0.2  Iris-setosa
# 5            5.0           3.6            NaN           0.2  Iris-setosa

# %%
#Dropping missing values

df.dropna()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 7              4.6           3.4            1.4           0.3     Iris-setosa
# 8              5.0           3.4            1.5           0.2     Iris-setosa
# 9              4.4           2.9            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [146 rows x 5 columns]

# %%
#dropping the columns which contain missing values

df.dropna(axis=1)
# Out:
#      PetalWidthCm
# 1             0.2
# 2             0.2
# 3             0.2
# 4             0.2
# 5             0.2
# ..            ...
# 146           2.3
# 147           1.9
# 148           2.0
# 149           2.3
# 150           1.8
#
# [150 rows x 1 columns]

# %%
# Drop rows with missing values in columns SepalLengthCm and SepalWidthCm. You can specify any number of column
df.dropna(subset=['SepalLengthCm', 'SepalWidthCm'])
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 5              5.0           3.6            NaN           0.2     Iris-setosa
# 6              5.4           3.9            NaN           0.4     Iris-setosa
# 7              4.6           3.4            1.4           0.3     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [148 rows x 5 columns]

# %%
# Drop rows with aleast two missing values
df.dropna(thresh=2)   #unfortunately no row contain two missing values
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           NaN            1.4           0.2             NaN
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              NaN           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            NaN           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.fillna('Keep Learning',inplace=True)
df.head()
# Out:
#    SepalLengthCm   SepalWidthCm  PetalLengthCm  PetalWidthCm        Species
# 1            5.1            3.5            1.4           0.2    Iris-setosa
# 2            4.9  Keep Learning            1.4           0.2  Keep Learning
# 3            4.7            3.2            1.3           0.2    Iris-setosa
# 4  Keep Learning            3.1            1.5           0.2    Iris-setosa
# 5            5.0            3.6  Keep Learning           0.2    Iris-setosa

# %%
#Done a mistake of using inplace=True. the whole dataset get changed. So need to reload it

# %%
df=pd.read_csv("C:\\Users\\abypt\\OneDrive\\Documents\\Harkeerat\\DATASETS for projects\\Iris_data_sample.csv",index_col=0, 
               na_values=["??","###"])
#As you can see NaN in row 2,4 and 5
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1            5.1           3.5            1.4           0.2  Iris-setosa
# 2            4.9           NaN            1.4           0.2          NaN
# 3            4.7           3.2            1.3           0.2  Iris-setosa
# 4            NaN           3.1            1.5           0.2  Iris-setosa
# 5            5.0           3.6            NaN           0.2  Iris-setosa

# %%
df.fillna(0.0,inplace=False)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           0.0            1.4           0.2             0.0
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              0.0           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            0.0           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#filling missing values with 0.0
df.fillna(0.0,inplace=False).head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1            5.1           3.5            1.4           0.2  Iris-setosa
# 2            4.9           0.0            1.4           0.2          0.0
# 3            4.7           3.2            1.3           0.2  Iris-setosa
# 4            0.0           3.1            1.5           0.2  Iris-setosa
# 5            5.0           3.6            0.0           0.2  Iris-setosa

# %%
#Filling missing value with mean.Notice that onl;u numeric values will be updated
df.fillna(df.mean(), inplace=False).head()
# Out:
# C:\Users\abypt\AppData\Local\Temp\ipykernel_25756\4052851017.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(), inplace=False).head()
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1       5.100000      3.500000       1.400000           0.2  Iris-setosa
# 2       4.900000      3.054362       1.400000           0.2          NaN
# 3       4.700000      3.200000       1.300000           0.2  Iris-setosa
# 4       5.851678      3.100000       1.500000           0.2  Iris-setosa
# 5       5.000000      3.600000       3.788514           0.2  Iris-setosa

# %%
df.fillna(df.median(), inplace=False).head()
# Out:
# C:\Users\abypt\AppData\Local\Temp\ipykernel_25756\362432479.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.median(), inplace=False).head()
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1            5.1           3.5            1.4           0.2  Iris-setosa
# 2            4.9           3.0            1.4           0.2          NaN
# 3            4.7           3.2            1.3           0.2  Iris-setosa
# 4            5.8           3.1            1.5           0.2  Iris-setosa
# 5            5.0           3.6            4.4           0.2  Iris-setosa

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1            5.1           3.5            1.4           0.2  Iris-setosa
# 2            4.9           NaN            1.4           0.2          NaN
# 3            4.7           3.2            1.3           0.2  Iris-setosa
# 4            NaN           3.1            1.5           0.2  Iris-setosa
# 5            5.0           3.6            NaN           0.2  Iris-setosa

# %%
# Forward filling
df.fillna(method='ffill', inplace=False).head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1            5.1           3.5            1.4           0.2  Iris-setosa
# 2            4.9           3.5            1.4           0.2  Iris-setosa
# 3            4.7           3.2            1.3           0.2  Iris-setosa
# 4            4.7           3.1            1.5           0.2  Iris-setosa
# 5            5.0           3.6            1.5           0.2  Iris-setosa

# %%
# Backward filling
df.fillna(method='bfill', inplace=False).head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1            5.1           3.5            1.4           0.2  Iris-setosa
# 2            4.9           3.2            1.4           0.2  Iris-setosa
# 3            4.7           3.2            1.3           0.2  Iris-setosa
# 4            5.0           3.1            1.5           0.2  Iris-setosa
# 5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1            5.1           3.5            1.4           0.2  Iris-setosa
# 2            4.9           NaN            1.4           0.2          NaN
# 3            4.7           3.2            1.3           0.2  Iris-setosa
# 4            NaN           3.1            1.5           0.2  Iris-setosa
# 5            5.0           3.6            NaN           0.2  Iris-setosa

# %%
df.interpolate(method='linear', inplace=False).head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1           5.10          3.50       1.400000           0.2  Iris-setosa
# 2           4.90          3.35       1.400000           0.2          NaN
# 3           4.70          3.20       1.300000           0.2  Iris-setosa
# 4           4.85          3.10       1.500000           0.2  Iris-setosa
# 5           5.00          3.60       1.466667           0.2  Iris-setosa

# %%
df.head(10)
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           NaN            1.4           0.2          NaN
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             NaN           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            NaN           0.2  Iris-setosa
# 6             5.4           3.9            NaN           0.4  Iris-setosa
# 7             4.6           3.4            1.4           0.3  Iris-setosa
# 8             5.0           3.4            1.5           0.2  Iris-setosa
# 9             4.4           2.9            1.4           0.2  Iris-setosa
# 10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
# Printing all the rows of the dataset
pd.set_option('display.max_rows', None)

# Display the dataset
print(df)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 1              5.1           3.5            1.4           0.2      Iris-setosa
# 2              4.9           NaN            1.4           0.2              NaN
# 3              4.7           3.2            1.3           0.2      Iris-setosa
# 4              NaN           3.1            1.5           0.2      Iris-setosa
# 5              5.0           3.6            NaN           0.2      Iris-setosa
# 6              5.4           3.9            NaN           0.4      Iris-setosa
# 7              4.6           3.4            1.4           0.3      Iris-setosa
# 8              5.0           3.4            1.5           0.2      Iris-setosa
# 9              4.4           2.9            1.4           0.2      Iris-setosa
# 10             4.9           3.1            1.5           0.1      Iris-setosa
# 11             5.4           3.7            1.5           0.2      Iris-setosa
# ...

# %%
df.duplicated()
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35      True
# 36     False
# 37     False
# 38      True
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# 66     False
# ...

# %%
df.duplicated().sum()
# Out:
# 3

# %%
# Dropping the duplicate values
df.drop_duplicates()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 1              5.1           3.5            1.4           0.2      Iris-setosa
# 2              4.9           NaN            1.4           0.2              NaN
# 3              4.7           3.2            1.3           0.2      Iris-setosa
# 4              NaN           3.1            1.5           0.2      Iris-setosa
# 5              5.0           3.6            NaN           0.2      Iris-setosa
# 6              5.4           3.9            NaN           0.4      Iris-setosa
# 7              4.6           3.4            1.4           0.3      Iris-setosa
# 8              5.0           3.4            1.5           0.2      Iris-setosa
# 9              4.4           2.9            1.4           0.2      Iris-setosa
# 10             4.9           3.1            1.5           0.1      Iris-setosa
# 11             5.4           3.7            1.5           0.2      Iris-setosa
# ...

# %%
# Detect outliers

df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     149.000000    149.000000     148.000000    150.000000
# mean        5.851678      3.054362       3.788514      1.198667
# std         0.824507      0.435034       1.757260      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.400000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000
